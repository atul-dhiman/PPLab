# %% [markdown]
# - *filter function*
# filter(function,sequence)
# - *map function*
# map(function,sequence)
# - _reduce function_
# reduce(function,sequence)

# %%
def check(x):
    if x%2==0:
        return x
# a=[10,20,21,35]
print(list(filter(check,range(0,20))))
# Out:
# [2, 4, 6, 8, 10, 12, 14, 16, 18]

# %%
List_A=[1,2,3,4]
List_B=[3,45,3,5]
def add(a,b):
    return a+b
List_C=list(map(add,List_A,List_B))
print(List_C)
# Out:
# [4, 47, 6, 9]

# %%
#reduce
List_A=[1,2,3,4]

# %%
def check(x):
    return x%2==0
a=[10,20,21,35]
print(list(filter(check,a)))
# Out:
# [10, 20]

# %%
tup=(15,)
tup1=(15)
print(type(tup),type(tup1))
# Out:
# <class 'tuple'> <class 'int'>

# %%
#divmod() function
print(divmod(10,3))
# Out:
# (3, 1)

# %%
tup=(2,5,10,9)
print(tup[1:5])
print(tup[1])
# Out:
# (5, 10, 9)
# 5

# %%
del tup[2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 del tup[2]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
del tup

# %%
#len
#max
#min
print(5 in tup)
print(20 in tup)
# Out:
# True
# False

# %%
# nested tuples
toppers=(("Akhilendra Dwivedi"),("Aakash"),("Keshav"),("Vijay"))

# %%
tup=(1,23,4,5,4,2,3,24,24,4)
print(tup.index(24))
# Out:
# 7

# %%
# tuple comprehension

# %%
def display(*args):
    print(args)
display(tup,tup[2:4])
# Out:
# ((1, 23, 4, 5, 4, 2, 3, 24, 24, 4), (4, 5))

# %%
tup=(56,3)
quo,rem=divmod(tup)
print(quo,rem)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 2
#       1 tup=(56,3)
# ----> 2 quo,rem=divmod(tup)
#       3 print(quo,rem)
#
# TypeError: divmod expected 2 arguments, got 1

# %%
tup=(56,3)
quo,rem=divmod(*tup)
print(quo,rem)
# Out:
# 18 2

# %%
#zip function
tup=(28,1,6,12)
lis=[10,20,30]
print(list(zip(tup,lis)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 4
#       2 tup=(28,1,6,12)
#       3 lis=[10,20,30]
# ----> 4 print(list(zip(tup,lis)))
#
# TypeError: 'list' object is not callable

# %% [markdown]
# ### Set
# - union
# - intersection

# %%
coders={"Keshav","Akhilendra"}
