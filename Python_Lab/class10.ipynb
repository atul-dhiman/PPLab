# %% [markdown]
# #### List

# %%
list_A=[1,2,"a",True,57,45,2,4,5]
print([list_A[::2]])
print([list_A[2:5]])
print([list_A[1::3]])
print([list_A[-3]])
# Out:
# [[1, 'a', 57, 2, 5]]
# [['a', True, 57]]
# [[2, 57, 4]]
# [2]

# %%
list_A.append(28)
list_A
# Out:
# [1, 2, 'a', True, 57, 45, 2, 4, 5, 28]

# %%
list_A[2]=[6,28,"AD"]

# %%
list_A
# Out:
# [1, 2, [6, 28, 'AD'], True, 57, 45, 9, 2, 4, 5, 28]

# %%
#delete_v/s_remove_in_list
list_A.remove(45)
list_A
# Out:
# [1, 2, [6, 28, 'AD'], True, 9, 2, 4, 5, 28]

# %%
del list_A[4]
list_A
# Out:
# [1, 2, [6, 28, 'AD'], True, 2, 4, 5, 28]

# %%
del list_A[:]
list_A
# Out:
# []

# %%
list_1=[1,"a","abc",[1,2,3],8.9]
list_1[3][1]
# Out:
# 2

# %%
list_2=list_1

# %%
list_3=list_1[2:5]

# %%
list_3
# Out:
# ['abc', [1, 2, 3], 8.9]

# %%
len(list_1)
# Out:
# 5

# %%
list_1.extend(list_2)
list_1
# Out:
# [1, 'a', 'abc', [1, 2, 3], 8.9, 1, 'a', 'abc', [1, 2, 3], 8.9]

# %%
print(list_2+list_3)
# Out:
# [1, 'a', 'abc', [1, 2, 3], 8.9, 1, 'a', 'abc', [1, 2, 3], 8.9, 'abc', [1, 2, 3], 8.9]

# %%
list_5=[1,2,3,4,5]
print(sum(list_5))
print(max(list_5))
print(min(list_5))
# Out:
# 15
# 5
# 1

# %%
5 in list_5
# Out:
# True

# %%
all(list_5)
# Out:
# True

# %%
any(list_5)
# Out:
# True

# %%
list_6=[12,6,1,29,2000,2001]
sorted(list_6)
# Out:
# [1, 6, 12, 29, 2000, 2001]

# %%
list_6.count(2000)
# Out:
# 1

# %%
list_6.insert(4,100)

# %%
list_6
# Out:
# [12, 6, 1, 29, 100, 2000, 2001]

# %%
list_6.reverse()
list_6
# Out:
# [2001, 2000, 100, 29, 1, 6, 12]

# %%
list_6.pop(2)
list_6
# Out:
# [2001, 2000, 29, 1, 6, 12]

# %% [markdown]
# ### Lists as Stack

# %%
Stack=[1,2,3,4,5,6]
Stack.append(7)
Stack.pop()
Stack[-1]
# Out:
# 6

# %% [markdown]
# ### Lists as Queue
# List comprehension
# List=[expression for variable in sequence]

# %%
cube=[]
cube=[i**3 for i in range(1,11)]
cube
# Out:
# [1, 8, 27, 64, 125, 216, 343, 512, 729, 1000]

# %%
print([[x,y] for x in [10,20,30] for y in [30,10,40] if x!=y])
# Out:
# [[10, 30], [10, 40], [20, 30], [20, 10], [20, 40], [30, 10], [30, 40]]
